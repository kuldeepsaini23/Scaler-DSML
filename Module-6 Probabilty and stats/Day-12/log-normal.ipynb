# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./waiting_time.csv")
data.head()
# Out:
#          time
# 0  184.003075
# 1   36.721521
# 2   29.970417
# 3   75.640285
# 4   61.489439

# %%
sns.histplot(data,bins=100)
# Right Skewed Distribution
# Out:
# <Axes: ylabel='Count'>

# %%
data_log =  np.log(data)
sns.histplot(data_log,bins=100)
# Out:
# <Axes: ylabel='Count'>

# %%
from scipy.stats import poisson

# %%
# Poisson is discrete, and we use probability mass function (PMF)
poisson.pmf(k=5, mu=3)
# Out:
# 0.10081881344492458

# %%
# typo Question
poisson.pmf(k=0, mu=3) + poisson.pmf(k=1, mu=3)
# Out:
# 0.1991482734714558

# %%
poisson.cdf(k=1, mu=3)
# Out:
# 0.1991482734714558

# %%
# Shop question
poisson.cdf(k=15, mu=18.5)
# Out:
# 0.2490276915128477

# %%
1 - poisson.cdf(k=7, mu=18.5)
# Out:
# 0.9979029280379949

# %% [markdown]
# ### Quizes

# %%
# Quiz - 1: Website sales
poisson.pmf(k=8, mu=10)
# Out:
# 0.11259903214902009

# %%
# Quiz-2: 
poisson.cdf(k=4, mu=4)
# Out:
# 0.6288369351798733

# %%
# 
1-poisson.cdf(k=11, mu=10)
# Out:
# 0.30322385369689386

# %%
poisson.cdf(k=1, mu=3/20)
# Out:
# 0.9898141728888165
