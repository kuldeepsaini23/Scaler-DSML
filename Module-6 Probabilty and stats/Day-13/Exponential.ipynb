# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import expon

# %%
# 1 - expon.cdf(x,scale)
# p[T > 10] [Receiving 240 messages per hour on average]
# What is the probability of waiting more than 10 seconds for next message

1 - expon.cdf(x=10,scale=15)
# Out:
# 0.513417119032592

# %%
expon.cdf(x=20,scale=50)
# Out:
# 0.3296799539643607

# %%
from scipy.stats import boxcox

# %%
# Random exponential data
data = np.random.exponential(size=1000)
data[:2]
# Out:
# array([1.36442503, 0.23212619])

# %%
# Expoential distribution
sns.distplot(data, hist=False,kde=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_4612\3108538199.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, hist=False,kde=True)
# <Axes: ylabel='Density'>

# %%
transformed_data, best_lambda = boxcox(data)
sns.distplot(transformed_data, hist=False,kde=True)
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_4612\1575682680.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(transformed_data, hist=False,kde=True)
# <Axes: ylabel='Density'>

# %%
best_lambda
# Out:
# 0.26836513812445917

# %% [markdown]
# ## Geometric

# %%
from scipy.stats import geom

# %%
geom.pmf(k=1,p=0.05) + geom.pmf(k=2,p=0.05)
# Out:
# 0.0975

# %%
geom.cdf(k=2,p=0.05)
# Out:
# 0.0975

# %%
expon.cdf(x=3/4,scale=4)
# Out:
# 0.17097088181959966
