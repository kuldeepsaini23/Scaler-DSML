# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df_height = df['Height']
sns.histplot(df_height)
# Out:
# 0    73.847017
# 1    68.781904
# 2    74.110105
# 3    71.730978
# 4    69.881796
# Name: Height, dtype: float64

# %%
# Calculate the mean of the height
mu = df_height.mean()
mu
# Out:
# 66.36755975482124

# %%
# Calculate the standard deviation of the height
sigma = df_height.std()
sigma
# Out:
# 3.8475281207732293

# %%
# Generate random samples from a normal distribution
df_height.sample(5)
# Out:
# 1915    61.795326
# 4895    70.474815
# 2199    63.399350
# 8201    60.209738
# 8389    69.610908
# Name: Height, dtype: float64

# %%
np.mean(df_height.sample(5))
# Out:
# 64.04847011849778

# %%
sample_5 = [np.mean(df_height.sample(5)) for i in range(1000)]

# %%
sample_5[:5]
# Out:
# [64.34682326634211,
#  65.94467286821927,
#  64.56208593685984,
#  63.78040960745632,
#  65.58182916794667]

# %%
sns.histplot(sample_5)
# Out:
# <Axes: ylabel='Count'>

# %%
sample_20 = [np.mean(df_height.sample(20)) for i in range(1000)]
sample_20[:5]
# Out:
# [66.21066762888265,
#  67.49007501281,
#  66.48375516750563,
#  64.25553766464955,
#  67.64049277357557]

# %%
sns.histplot(sample_20)
# Out:
# <Axes: ylabel='Count'>

# %%
# population mean
mu = df_height.mean()

# population SD
sigma = df_height.std()

# sample-5 mean
mu_5 = np.mean(sample_5)
# sample-5 SD
sigma_5 = np.std(sample_5)

# sample-20 mean
mu_20 = np.mean(sample_20)
# sample-5 SD
sigma_20 = np.std(sample_20)

# %%
print(mu, mu_5, mu_20)
print(sigma, sigma_5, sigma_20)
# Out:
# 66.36755975482124 66.37955960380714 66.39078639015331
# 3.8475281207732293 1.7461813010050709 0.8655213044024113

# %%
norm.cdf(1.1)
# Out:
# 0.8643339390536173

# %%
std = 15/np.sqrt(50)
# Out:
# -2.3570226039551585

# %%
norm.cdf((75-80)/std)
# Out:
# 0.0092110627270495

# %%
norm.ppf(0.975)
# Out:
# 1.959963984540054

# %% [markdown]
# ### BootStraped

# %%
survey_1 = [35,36,33,37,34,35]
np.mean(survey_1)
# Out:
# 35.0

# %%
survey_2 = [20,37,17,50,53,33]
np.mean(survey_2)
# Out:
# 35.0

# %%
# Bootstrap sampling with replacement 
n = 6
bootstrapped_samples = np.random.choice(survey_1,size=n)
bootstrapped_samples
np.mean(bootstrapped_samples)
# Out:
# 34.166666666666664

# %%
bootstrapped_samples = np.random.choice(survey_2,size=n)
np.mean(bootstrapped_samples)
# Out:
# 26.666666666666668

# %%
bootstrapped_means_survey_1 = []
for i in range(10000):
    bootstrapped_samples = np.random.choice(survey_1,size=n)
    bootstrapped_samples_mean = np.mean(bootstrapped_samples)
    bootstrapped_means_survey_1.append(bootstrapped_samples_mean)

sns.histplot(bootstrapped_means_survey_1)
# Out:
# <Axes: ylabel='Count'>

# %%
bootstrapped_means_survey_2 = []
for i in range(10000):
    bootstrapped_samples = np.random.choice(survey_2,size=n)
    bootstrapped_samples_mean = np.mean(bootstrapped_samples)
    bootstrapped_means_survey_2.append(bootstrapped_samples_mean)

sns.histplot(bootstrapped_means_survey_2)
# Out:
# <Axes: ylabel='Count'>

# %%
x1 = np.percentile(bootstrapped_means_survey_1,2.5)
x1
# Out:
# 34.0

# %%
x2 = np.percentile(bootstrapped_means_survey_1,97.5)
x2
# Out:
# 36.0

# %%
x1 = np.percentile(bootstrapped_means_survey_2,2.5)
x1
# Out:
# 24.0

# %%
x1 = np.percentile(bootstrapped_means_survey_2,97.5)
x1
# Out:
# 46.0
