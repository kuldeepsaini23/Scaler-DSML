# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sales.csv')
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 726554  554268    84997C      CHILDRENS CUTLERY POLKADOT BLUE       1.0
# 726555  554268     23192  BUNDLE OF 3 ALPHABET EXERCISE BOOKS       1.0
# 726556  554268     23191         BUNDLE OF 3 RETRO NOTE BOOKS       1.0
# 726557  554268     23190  BUNDLE OF 3 SCHOOL EXERCISE BOOKS         1.0
# 726558  554268     23165                     LARGE CERAMIC TO       NaN
#
#                 InvoiceDate  Price  Customer ID         Country
# 0       2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1       2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2       2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3       2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4       2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                     ...    ...          ...             ...
# 726554  2011-05-23 12:59:00   4.15      15311.0  United Kingdom
# 726555  2011-05-23 12:59:00   1.65      15311.0  United Kingdom
# 726556  2011-05-23 12:59:00   1.65      15311.0  United Kingdom
# 726557  2011-05-23 12:59:00   1.65      15311.0  United Kingdom
# 726558                  NaN    NaN          NaN             NaN
#
# [726559 rows x 8 columns]

# %% [markdown]
# ## Sales

# %%
df['sales']=df['Quantity']*df['Price']

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 726554  554268    84997C      CHILDRENS CUTLERY POLKADOT BLUE       1.0
# 726555  554268     23192  BUNDLE OF 3 ALPHABET EXERCISE BOOKS       1.0
# 726556  554268     23191         BUNDLE OF 3 RETRO NOTE BOOKS       1.0
# 726557  554268     23190  BUNDLE OF 3 SCHOOL EXERCISE BOOKS         1.0
# 726558  554268     23165                     LARGE CERAMIC TO       NaN
#
#                 InvoiceDate  Price  Customer ID         Country   sales
# 0       2009-12-01 07:45:00   6.95      13085.0  United Kingdom   83.40
# 1       2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.00
# 2       2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.00
# 3       2009-12-01 07:45:00   2.10      13085.0  United Kingdom  100.80
# 4       2009-12-01 07:45:00   1.25      13085.0  United Kingdom   30.00
# ...                     ...    ...          ...             ...     ...
# 726554  2011-05-23 12:59:00   4.15      15311.0  United Kingdom    4.15
# 726555  2011-05-23 12:59:00   1.65      15311.0  United Kingdom    1.65
# 726556  2011-05-23 12:59:00   1.65      15311.0  United Kingdom    1.65
# 726557  2011-05-23 12:59:00   1.65      15311.0  United Kingdom    1.65
# 726558                  NaN    NaN          NaN             NaN     NaN
#
# [726559 rows x 9 columns]

# %% [markdown]
# # DATE

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])
df['Date']=df['InvoiceDate'].dt.date

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 726554  554268    84997C      CHILDRENS CUTLERY POLKADOT BLUE       1.0
# 726555  554268     23192  BUNDLE OF 3 ALPHABET EXERCISE BOOKS       1.0
# 726556  554268     23191         BUNDLE OF 3 RETRO NOTE BOOKS       1.0
# 726557  554268     23190  BUNDLE OF 3 SCHOOL EXERCISE BOOKS         1.0
# 726558  554268     23165                     LARGE CERAMIC TO       NaN
#
#                InvoiceDate  Price  Customer ID         Country        Date
# 0      2009-12-01 07:45:00   6.95      13085.0  United Kingdom  2009-12-01
# 1      2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009-12-01
# 2      2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009-12-01
# 3      2009-12-01 07:45:00   2.10      13085.0  United Kingdom  2009-12-01
# 4      2009-12-01 07:45:00   1.25      13085.0  United Kingdom  2009-12-01
# ...                    ...    ...          ...             ...         ...
# 726554 2011-05-23 12:59:00   4.15      15311.0  United Kingdom  2011-05-23
# 726555 2011-05-23 12:59:00   1.65      15311.0  United Kingdom  2011-05-23
# 726556 2011-05-23 12:59:00   1.65      15311.0  United Kingdom  2011-05-23
# 726557 2011-05-23 12:59:00   1.65      15311.0  United Kingdom  2011-05-23
# 726558                 NaT    NaN          NaN             NaN         NaT
#
# [726559 rows x 9 columns]

# %%
df_france = df[df['Country'] == "France"]
df_france
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 71      489439     22065      CHRISTMAS PUDDING TRINKET POT       12.0
# 72      489439     22138       BAKING SET 9 PIECE RETROSPOT        9.0
# 73      489439     22139   RETRO SPOT TEA SET CERAMIC 11 PC        9.0
# 74      489439     22352    LUNCHBOX WITH CUTLERY RETROSPOT       12.0
# 75      489439    85014A    BLACK/BLUE DOTS RUFFLED UMBRELLA       3.0
# ...        ...       ...                                 ...       ...
# 725923  554134     20983  12 PENCILS TALL TUBE RED RETROSPOT      12.0
# 725924  554134     20981       12 PENCILS TALL TUBE WOODLAND      12.0
# 725925  554134     21245               GREEN POLKADOT PLATE        8.0
# 725926  554134     84380   SET OF 3 BUTTERFLY COOKIE CUTTERS      12.0
# 725927  554134      POST                             POSTAGE       2.0
#
#                InvoiceDate  Price  Customer ID Country  sales        Date
# 71     2009-12-01 09:28:00   1.45      12682.0  France  17.40  2009-12-01
# 72     2009-12-01 09:28:00   4.95      12682.0  France  44.55  2009-12-01
# 73     2009-12-01 09:28:00   4.95      12682.0  France  44.55  2009-12-01
# 74     2009-12-01 09:28:00   2.55      12682.0  France  30.60  2009-12-01
# 75     2009-12-01 09:28:00   5.95      12682.0  France  17.85  2009-12-01
# ...                    ...    ...          ...     ...    ...         ...
# 725923 2011-05-23 09:48:00   0.85      12583.0  France  10.20  2011-05-23
# 725924 2011-05-23 09:48:00   0.85      12583.0  France  10.20  2011-05-23
# 725925 2011-05-23 09:48:00   1.69      12583.0  France  13.52  2011-05-23
# 725926 2011-05-23 09:48:00   1.25      12583.0  France  15.00  2011-05-23
# 725927 2011-05-23 09:48:00  18.00      12583.0  France  36.00  2011-05-23
#
# [8683 rows x 10 columns]

# %%
df_france = df_france.groupby("Date")['sales'].sum().to_frame()
df_france
# Out:
#               sales
# Date
# 2009-12-01  1024.29
# 2009-12-02   549.33
# 2009-12-03  -143.90
# 2009-12-04   636.90
# 2009-12-06   817.44
# ...             ...
# 2011-05-18   869.53
# 2011-05-19   914.51
# 2011-05-20  1100.55
# 2011-05-22   910.71
# 2011-05-23   421.96
#
# [244 rows x 1 columns]

# %%
df_france.sort_values("sales", ascending=False).head()
# Out:
#                sales
# Date
# 2010-08-09  12726.01
# 2010-05-06   8490.90
# 2011-03-31   5593.59
# 2010-11-19   5084.89
# 2010-10-11   4876.40
