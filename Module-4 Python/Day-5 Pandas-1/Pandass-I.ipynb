# %%
'''
To install pandas, use the following command:
  - pip install pandas
  - No installation required if you are using Anaconda or Colab
'''
# Out:
# '\nTo install pandas, use the following command:\n  - pip install pandas\n  - No installation required if you are using Anaconda or Colab\n'

# %%
import pandas as pd

# %%
import numpy as np

# %%
#Loading data in pandas
df = pd.read_csv('mckinsey.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(8)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail(7)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape # Works the same was as in Numpy
# Out:
# (1704, 6)

# %% [markdown]
# # COlumn

# %%
df.columns #dataframe have an attribute called columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys() #dataframe have an Method called keys
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
# Index is a special Pandas objects which store an immutabe data

# %%
df["country"].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
type(df["country"].head())
# Out:
# pandas.core.series.Series

# %%
df[["country", "life_exp"]].head()
# Out:
#        country  life_exp
# 0  Afghanistan    28.801
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088

# %%
type(df[["country", "life_exp"]].head())
# Out:
# pandas.core.frame.DataFrame

# %%
df[["country"]].head()
# Out:
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %% [markdown]
# ### Unique Values

# %%
df["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
type(df["country"].unique())
# Out:
# numpy.ndarray

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11892\1660334235.py in ?()
# ----> 1 df.unique()
#
# c:\Users\kulde\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df["country"].nunique()
# Out:
# 142

# %%
df.nunique()
# Out:
# country        142
# year            12
# population    1704
# continent        5
# life_exp      1626
# gdp_cap       1704
# dtype: int64

# %%
# Count of every unique element in the country column
df["country"].value_counts()
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
type(df["country"].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Rename Column

# %%
df.rename({"population": "POPULDATION", "country": "NATION"}, axis=1)
# Out:
#            NATION  year  POPULDATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952      8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957      9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962     10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967     11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972     13079460      Asia    36.088  739.981106
# ...           ...   ...          ...       ...       ...         ...
# 1699     Zimbabwe  1987      9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992     10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997     11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002     11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007     12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns = {"population": "POPULDATION", "country": "NATION"})
# Out:
#            NATION  year  POPULDATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952      8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957      9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962     10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967     11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972     13079460      Asia    36.088  739.981106
# ...           ...   ...          ...       ...       ...         ...
# 1699     Zimbabwe  1987      9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992     10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997     11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002     11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007     12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# This will change in original dataframe
df.rename(columns = {"population": "POPULDATION", "country": "NATION"}, inplace=True)

# %%
df
# Out:
#            NATION  year  POPULDATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952      8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957      9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962     10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967     11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972     13079460      Asia    36.088  739.981106
# ...           ...   ...          ...       ...       ...         ...
# 1699     Zimbabwe  1987      9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992     10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997     11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002     11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007     12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#! Bad Practice
df.year
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
#Instead Do this
df["year"]
#Instead do this
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %% [markdown]
# #### Delete Column

# %%
df.drop("year", axis=1)
# Out:
#            NATION  POPULDATION continent  life_exp     gdp_cap
# 0     Afghanistan      8425333      Asia    28.801  779.445314
# 1     Afghanistan      9240934      Asia    30.332  820.853030
# 2     Afghanistan     10267083      Asia    31.997  853.100710
# 3     Afghanistan     11537966      Asia    34.020  836.197138
# 4     Afghanistan     13079460      Asia    36.088  739.981106
# ...           ...          ...       ...       ...         ...
# 1699     Zimbabwe      9216418    Africa    62.351  706.157306
# 1700     Zimbabwe     10704340    Africa    60.377  693.420786
# 1701     Zimbabwe     11404948    Africa    46.809  792.449960
# 1702     Zimbabwe     11926563    Africa    39.989  672.038623
# 1703     Zimbabwe     12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.drop(columns="year")
# Out:
#            NATION  POPULDATION continent  life_exp     gdp_cap
# 0     Afghanistan      8425333      Asia    28.801  779.445314
# 1     Afghanistan      9240934      Asia    30.332  820.853030
# 2     Afghanistan     10267083      Asia    31.997  853.100710
# 3     Afghanistan     11537966      Asia    34.020  836.197138
# 4     Afghanistan     13079460      Asia    36.088  739.981106
# ...           ...          ...       ...       ...         ...
# 1699     Zimbabwe      9216418    Africa    62.351  706.157306
# 1700     Zimbabwe     10704340    Africa    60.377  693.420786
# 1701     Zimbabwe     11404948    Africa    46.809  792.449960
# 1702     Zimbabwe     11926563    Africa    39.989  672.038623
# 1703     Zimbabwe     12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#            NATION  year  POPULDATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952      8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957      9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962     10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967     11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972     13079460      Asia    36.088  739.981106
# ...           ...   ...          ...       ...       ...         ...
# 1699     Zimbabwe  1987      9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992     10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997     11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002     11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007     12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop("continent",axis=1, inplace=True)

# %%
df
# Out:
#            NATION  year  POPULDATION  life_exp     gdp_cap
# 0     Afghanistan  1952      8425333    28.801  779.445314
# 1     Afghanistan  1957      9240934    30.332  820.853030
# 2     Afghanistan  1962     10267083    31.997  853.100710
# 3     Afghanistan  1967     11537966    34.020  836.197138
# 4     Afghanistan  1972     13079460    36.088  739.981106
# ...           ...   ...          ...       ...         ...
# 1699     Zimbabwe  1987      9216418    62.351  706.157306
# 1700     Zimbabwe  1992     10704340    60.377  693.420786
# 1701     Zimbabwe  1997     11404948    46.809  792.449960
# 1702     Zimbabwe  2002     11926563    39.989  672.038623
# 1703     Zimbabwe  2007     12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %% [markdown]
# ## Generate Column

# %%
df["Year + 7"] = df["year"] + 7

# %%
df.head()
# Out:
#         NATION  year  POPULDATION  life_exp     gdp_cap  Year + 7
# 0  Afghanistan  1952      8425333    28.801  779.445314      1959
# 1  Afghanistan  1957      9240934    30.332  820.853030      1964
# 2  Afghanistan  1962     10267083    31.997  853.100710      1969
# 3  Afghanistan  1967     11537966    34.020  836.197138      1974
# 4  Afghanistan  1972     13079460    36.088  739.981106      1979

# %%
# Calculating the Total GDP
# Gdp = GDP per capita * Population
df["Total GDP"] = df["gdp_cap"] * df["POPULDATION"]

# %%
df
# Out:
#            NATION  year  POPULDATION  life_exp     gdp_cap  Year + 7  \
# 0     Afghanistan  1952      8425333    28.801  779.445314      1959
# 1     Afghanistan  1957      9240934    30.332  820.853030      1964
# 2     Afghanistan  1962     10267083    31.997  853.100710      1969
# 3     Afghanistan  1967     11537966    34.020  836.197138      1974
# 4     Afghanistan  1972     13079460    36.088  739.981106      1979
# ...           ...   ...          ...       ...         ...       ...
# 1699     Zimbabwe  1987      9216418    62.351  706.157306      1994
# 1700     Zimbabwe  1992     10704340    60.377  693.420786      1999
# 1701     Zimbabwe  1997     11404948    46.809  792.449960      2004
# 1702     Zimbabwe  2002     11926563    39.989  672.038623      2009
# 1703     Zimbabwe  2007     12311143    43.487  469.709298      2014
#
#          Total GDP
# 0     6.567086e+09
# 1     7.585449e+09
# 2     8.758856e+09
# 3     9.648014e+09
# 4     9.678553e+09
# ...

# %%
df.drop("Year + 7", axis = 1, inplace=True)

# %%
df
# Out:
#            NATION  year  POPULDATION  life_exp     gdp_cap     Total GDP
# 0     Afghanistan  1952      8425333    28.801  779.445314  6.567086e+09
# 1     Afghanistan  1957      9240934    30.332  820.853030  7.585449e+09
# 2     Afghanistan  1962     10267083    31.997  853.100710  8.758856e+09
# 3     Afghanistan  1967     11537966    34.020  836.197138  9.648014e+09
# 4     Afghanistan  1972     13079460    36.088  739.981106  9.678553e+09
# ...           ...   ...          ...       ...         ...           ...
# 1699     Zimbabwe  1987      9216418    62.351  706.157306  6.508241e+09
# 1700     Zimbabwe  1992     10704340    60.377  693.420786  7.422612e+09
# 1701     Zimbabwe  1997     11404948    46.809  792.449960  9.037851e+09
# 1702     Zimbabwe  2002     11926563    39.989  672.038623  8.015111e+09
# 1703     Zimbabwe  2007     12311143    43.487  469.709298  5.782658e+09
#
# [1704 rows x 6 columns]

# %%
df["random"] = [i**3 for i in range(1704)]

# %%
df
# Out:
#            NATION  year  POPULDATION  life_exp     gdp_cap     Total GDP  \
# 0     Afghanistan  1952      8425333    28.801  779.445314  6.567086e+09
# 1     Afghanistan  1957      9240934    30.332  820.853030  7.585449e+09
# 2     Afghanistan  1962     10267083    31.997  853.100710  8.758856e+09
# 3     Afghanistan  1967     11537966    34.020  836.197138  9.648014e+09
# 4     Afghanistan  1972     13079460    36.088  739.981106  9.678553e+09
# ...           ...   ...          ...       ...         ...           ...
# 1699     Zimbabwe  1987      9216418    62.351  706.157306  6.508241e+09
# 1700     Zimbabwe  1992     10704340    60.377  693.420786  7.422612e+09
# 1701     Zimbabwe  1997     11404948    46.809  792.449960  9.037851e+09
# 1702     Zimbabwe  2002     11926563    39.989  672.038623  8.015111e+09
# 1703     Zimbabwe  2007     12311143    43.487  469.709298  5.782658e+09
#
#           random
# 0              0
# 1              1
# 2              8
# 3             27
# ...

# %%
df["weird"] = [i**3 for i in range(1700)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Scaler\Module-4 Python\Day-5 Pandas-1\Pandass-I.ipynb Cell 51 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Scaler/Module-4%20Python/Day-5%20Pandas-1/Pandass-I.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> df["weird"] = [i**3 for i in range(1700)]
#
# File c:\Users\kulde\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File c:\Users\kulde\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4303, in DataFrame._set_item(self, key, value)
#    4293 def _set_item(self, key, value) -> None:
#    4294     """
#    4295     Add series to DataFrame in specified column.
#    4296
#    (...)
# ...

# %%
df["weird"] = [i**3 for i in range(1708)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Scaler\Module-4 Python\Day-5 Pandas-1\Pandass-I.ipynb Cell 52 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Scaler/Module-4%20Python/Day-5%20Pandas-1/Pandass-I.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> df["weird"] = [i**3 for i in range(1708)]
#
# File c:\Users\kulde\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File c:\Users\kulde\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4303, in DataFrame._set_item(self, key, value)
#    4293 def _set_item(self, key, value) -> None:
#    4294     """
#    4295     Add series to DataFrame in specified column.
#    4296
#    (...)
# ...

# %%
df.drop(columns = ["random", "Total GDP"], inplace=True)

# %%
df
# Out:
#            NATION  year  POPULDATION  life_exp     gdp_cap
# 0     Afghanistan  1952      8425333    28.801  779.445314
# 1     Afghanistan  1957      9240934    30.332  820.853030
# 2     Afghanistan  1962     10267083    31.997  853.100710
# 3     Afghanistan  1967     11537966    34.020  836.197138
# 4     Afghanistan  1972     13079460    36.088  739.981106
# ...           ...   ...          ...       ...         ...
# 1699     Zimbabwe  1987      9216418    62.351  706.157306
# 1700     Zimbabwe  1992     10704340    60.377  693.420786
# 1701     Zimbabwe  1997     11404948    46.809  792.449960
# 1702     Zimbabwe  2002     11926563    39.989  672.038623
# 1703     Zimbabwe  2007     12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.rename(columns = {"NATION": "nation", "POPULDATION":"population"}, inplace=True)

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.index = np.arange(10, df.shape[0]+10, dtype="float")

# %%
df
# Out:
#              nation  year  population  life_exp     gdp_cap
# 10.0    Afghanistan  1952     8425333    28.801  779.445314
# 11.0    Afghanistan  1957     9240934    30.332  820.853030
# 12.0    Afghanistan  1962    10267083    31.997  853.100710
# 13.0    Afghanistan  1967    11537966    34.020  836.197138
# 14.0    Afghanistan  1972    13079460    36.088  739.981106
# ...             ...   ...         ...       ...         ...
# 1709.0     Zimbabwe  1987     9216418    62.351  706.157306
# 1710.0     Zimbabwe  1992    10704340    60.377  693.420786
# 1711.0     Zimbabwe  1997    11404948    46.809  792.449960
# 1712.0     Zimbabwe  2002    11926563    39.989  672.038623
# 1713.0     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.index[1]
# df.index takes the implicit index of the dataframe and returns the explicit index
# Out:
# 11.0

# %%
sample = df.head()

# %%
sample
# Out:
#            nation  year  population  life_exp     gdp_cap
# 10.0  Afghanistan  1952     8425333    28.801  779.445314
# 11.0  Afghanistan  1957     9240934    30.332  820.853030
# 12.0  Afghanistan  1962    10267083    31.997  853.100710
# 13.0  Afghanistan  1967    11537966    34.020  836.197138
# 14.0  Afghanistan  1972    13079460    36.088  739.981106

# %%
sample.index = ["a", "b", "c", "d", "e"]

# %%
sample
# Out:
#         nation  year  population  life_exp     gdp_cap
# a  Afghanistan  1952     8425333    28.801  779.445314
# b  Afghanistan  1957     9240934    30.332  820.853030
# c  Afghanistan  1962    10267083    31.997  853.100710
# d  Afghanistan  1967    11537966    34.020  836.197138
# e  Afghanistan  1972    13079460    36.088  739.981106

# %%
df
# Out:
#              nation  year  population  life_exp     gdp_cap
# 10.0    Afghanistan  1952     8425333    28.801  779.445314
# 11.0    Afghanistan  1957     9240934    30.332  820.853030
# 12.0    Afghanistan  1962    10267083    31.997  853.100710
# 13.0    Afghanistan  1967    11537966    34.020  836.197138
# 14.0    Afghanistan  1972    13079460    36.088  739.981106
# ...             ...   ...         ...       ...         ...
# 1709.0     Zimbabwe  1987     9216418    62.351  706.157306
# 1710.0     Zimbabwe  1992    10704340    60.377  693.420786
# 1711.0     Zimbabwe  1997    11404948    46.809  792.449960
# 1712.0     Zimbabwe  2002    11926563    39.989  672.038623
# 1713.0     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.index = np.arange(10, df.shape[0]+10, dtype="int")

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333    28.801  779.445314
# 11    Afghanistan  1957     9240934    30.332  820.853030
# 12    Afghanistan  1962    10267083    31.997  853.100710
# 13    Afghanistan  1967    11537966    34.020  836.197138
# 14    Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1709     Zimbabwe  1987     9216418    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
s1 = df["nation"]

# %%
s1
# Out:
# 10      Afghanistan
# 11      Afghanistan
# 12      Afghanistan
# 13      Afghanistan
# 14      Afghanistan
#            ...
# 1709       Zimbabwe
# 1710       Zimbabwe
# 1711       Zimbabwe
# 1712       Zimbabwe
# 1713       Zimbabwe
# Name: nation, Length: 1704, dtype: object

# %%
s1[10] #Indexing using explicit index
# Out:
# 'Afghanistan'

# %%
s1[20:24] # Slicing - Implict Indexing
# Out:
# 30    Albania
# 31    Albania
# 32    Albania
# 33    Albania
# Name: nation, dtype: object

# %% [markdown]
# ## iloc and loc

# %%
df.loc[10]
# Out:
# nation        Afghanistan
# year                 1952
# population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: 10, dtype: object

# %%
df.loc[1:3]
# Out:
# Empty DataFrame
# Columns: [nation, year, population, life_exp, gdp_cap]
# Index: []

# %%
df.loc[10:20] #Ending index is inclusive
# Out:
#          nation  year  population  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333    28.801  779.445314
# 11  Afghanistan  1957     9240934    30.332  820.853030
# 12  Afghanistan  1962    10267083    31.997  853.100710
# 13  Afghanistan  1967    11537966    34.020  836.197138
# 14  Afghanistan  1972    13079460    36.088  739.981106
# 15  Afghanistan  1977    14880372    38.438  786.113360
# 16  Afghanistan  1982    12881816    39.854  978.011439
# 17  Afghanistan  1987    13867957    40.822  852.395945
# 18  Afghanistan  1992    16317921    41.674  649.341395
# 19  Afghanistan  1997    22227415    41.763  635.341351
# 20  Afghanistan  2002    25268405    42.129  726.734055

# %%
'''
IMPORTANT NOTE: 
  - loc is used for explicit indexing
  - iloc is used for implicit indexing

  This slicing rule is only applied on loc
  SLICING: using loc df.loc[starting_index:ending_index]
  - Starting index is inclusive
  - Ending index is inclusive 

'''
# Out:
# '\nIMPORTANT NOTE: \n  - loc is used for explicit indexing\n  - iloc is used for implicit indexing\n\n  This slicing rule is only applied on loc\n  SLICING: using loc df.loc[starting_index:ending_index]\n  - Starting index is inclusive\n  - Ending index is inclusive \n\n'

# %% [markdown]
# ##### iloc

# %%
df.iloc[10]
# Out:
# nation        Afghanistan
# year                 2002
# population       25268405
# life_exp           42.129
# gdp_cap        726.734055
# Name: 20, dtype: object

# %%
df.iloc[[1,10,100]]
# Out:
#           nation  year  population  life_exp     gdp_cap
# 11   Afghanistan  1957     9240934    30.332  820.853030
# 20   Afghanistan  2002    25268405    42.129  726.734055
# 110   Bangladesh  1972    70759295    45.252  630.233627

# %%
df.iloc[1:10]
# Out:
#          nation  year  population  life_exp     gdp_cap
# 11  Afghanistan  1957     9240934    30.332  820.853030
# 12  Afghanistan  1962    10267083    31.997  853.100710
# 13  Afghanistan  1967    11537966    34.020  836.197138
# 14  Afghanistan  1972    13079460    36.088  739.981106
# 15  Afghanistan  1977    14880372    38.438  786.113360
# 16  Afghanistan  1982    12881816    39.854  978.011439
# 17  Afghanistan  1987    13867957    40.822  852.395945
# 18  Afghanistan  1992    16317921    41.674  649.341395
# 19  Afghanistan  1997    22227415    41.763  635.341351

# %%
df.iloc[-1]
# Out:
# nation          Zimbabwe
# year                2007
# population      12311143
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1713, dtype: object

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kulde\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:4484, in pandas._libs.hashtable.Int32HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:4508, in pandas._libs.hashtable.Int32HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\Scaler\Module-4 Python\Day-5 Pandas-1\Pandass-I.ipynb Cell 80 line 1
# ...

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333    28.801  779.445314
# 11    Afghanistan  1957     9240934    30.332  820.853030
# 12    Afghanistan  1962    10267083    31.997  853.100710
# 13    Afghanistan  1967    11537966    34.020  836.197138
# 14    Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1709     Zimbabwe  1987     9216418    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index       nation  year  population  life_exp     gdp_cap
# 0        10  Afghanistan  1952     8425333    28.801  779.445314
# 1        11  Afghanistan  1957     9240934    30.332  820.853030
# 2        12  Afghanistan  1962    10267083    31.997  853.100710
# 3        13  Afghanistan  1967    11537966    34.020  836.197138
# 4        14  Afghanistan  1972    13079460    36.088  739.981106
# ...     ...          ...   ...         ...       ...         ...
# 1699   1709     Zimbabwe  1987     9216418    62.351  706.157306
# 1700   1710     Zimbabwe  1992    10704340    60.377  693.420786
# 1701   1711     Zimbabwe  1997    11404948    46.809  792.449960
# 1702   1712     Zimbabwe  2002    11926563    39.989  672.038623
# 1703   1713     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index(drop = True,inplace=True)

# %%
df
# Out:
#       index       nation  year  population  life_exp     gdp_cap
# 0        10  Afghanistan  1952     8425333    28.801  779.445314
# 1        11  Afghanistan  1957     9240934    30.332  820.853030
# 2        12  Afghanistan  1962    10267083    31.997  853.100710
# 3        13  Afghanistan  1967    11537966    34.020  836.197138
# 4        14  Afghanistan  1972    13079460    36.088  739.981106
# ...     ...          ...   ...         ...       ...         ...
# 1699   1709     Zimbabwe  1987     9216418    62.351  706.157306
# 1700   1710     Zimbabwe  1992    10704340    60.377  693.420786
# 1701   1711     Zimbabwe  1997    11404948    46.809  792.449960
# 1702   1712     Zimbabwe  2002    11926563    39.989  672.038623
# 1703   1713     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop(columns = ["index"], inplace=True)

# %%
df
# Out:
#            nation  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]
